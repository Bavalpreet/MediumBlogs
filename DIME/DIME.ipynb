# %% [markdown]
# #Experiment 1

# %%
# !pip install sentence-transformers faiss-cpu numpy tabulate tqdm
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: tabulate in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: tqdm in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (4.66.5)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.7.1-cp312-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Requirement already satisfied: scikit-learn in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Pillow in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: packaging in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: filelock in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Requirement already satisfied: setuptools in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.21.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Downloading sentence_transformers-5.0.0-py3-none-any.whl (470 kB)
# Downloading faiss_cpu-1.11.0-cp312-cp312-macosx_14_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 47.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# Downloading torch-2.7.1-cp312-none-macosx_11_0_arm64.whl (68.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 91.1 MB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.53.2-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 97.1 MB/s eta 0:00:00
# Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 76.8 MB/s eta 0:00:00
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 77.9 MB/s eta 0:00:00
# Downloading tokenizers-0.21.2-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 75.1 MB/s eta 0:00:00
# Installing collected packages: sympy, safetensors, hf-xet, faiss-cpu, torch, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed faiss-cpu-1.11.0 hf-xet-1.1.5 huggingface-hub-0.33.4 safetensors-0.5.3 sentence-transformers-5.0.0 sympy-1.14.0 tokenizers-0.21.2 torch-2.7.1 transformers-4.53.2

# %%
"""dime_demo.py — Minimal but runnable DIME pipeline"""
import faiss, numpy as np
from sentence_transformers import SentenceTransformer
from tabulate import tabulate
from tqdm import tqdm

# ---------------------------------------------------------------------
# 1. Toy corpus (replace with your own docs) ---------------------------
# ---------------------------------------------------------------------
CORPUS = {
    "doc_1": "Paris is the capital of France and a major European city.",
    "doc_2": "Berlin is the vibrant capital of Germany, known for its art scene.",
    "doc_3": "Rome, the capital of Italy, hosts the Vatican City.",
    "doc_4": "Toronto is the largest city in Canada and the capital of Ontario.",
    "doc_5": "The City of Light is a popular nickname for Paris in France.",
}

QUERIES = [
    "capital of France",
    "German capital city",
]

# ---------------------------------------------------------------------
# 2. Encoder & embeddings ---------------------------------------------
# ---------------------------------------------------------------------
print("Loading SBERT …")
model = SentenceTransformer("all-MiniLM-L6-v2")  # 384‑D embeddings
ids, docs = list(CORPUS.keys()), list(CORPUS.values())
embs = model.encode(docs, convert_to_numpy=True, show_progress_bar=False)

# ---------------------------------------------------------------------
# 3. Build FAISS index -------------------------------------------------
# ---------------------------------------------------------------------
dim = embs.shape[1]
index = faiss.IndexFlatIP(dim)  # inner‑product (dot‑product) search
index.add(embs)
print(f"Indexed {index.ntotal} docs, dim={dim}")

# ---------------------------------------------------------------------
# 4. DIME utilities ----------------------------------------------------
# ---------------------------------------------------------------------

def softmax(x, tau=1.0):
    x = (x / tau) - np.max(x)  # avoid overflow
    return np.exp(x) / np.exp(x).sum()


def dime_filter(q_vec, top_vecs, top_scores, keep_frac=0.6, tau=1.0, weighted=True):
    """Return filtered (masked) query vector q̃."""
    if weighted:
        w = softmax(top_scores, tau)
        centroid = np.average(top_vecs, axis=0, weights=w)
    else:
        centroid = top_vecs.mean(axis=0)

    # Dimension importance & mask
    importance = q_vec * centroid  # element‑wise product
    thresh = np.quantile(importance, 1 - keep_frac)
    q_tilde = np.where(importance >= thresh, q_vec, 0.0)
    return q_tilde


def search(q_vec, k=3):
    q_norm = q_vec / np.linalg.norm(q_vec)  # SBERT vectors are L2‑norm sensitive
    scores, idx = index.search(q_norm[None, :], k)
    return scores[0], idx[0]


# ---------------------------------------------------------------------
# 5. Run everything ----------------------------------------------------
# ---------------------------------------------------------------------
for q in QUERIES:
    print("=== QUERY:", q, "===")
    q_vec = model.encode(q, convert_to_numpy=True)

    # First‑stage retrieval
    scores1, idx1 = search(q_vec, k=5)
    top_vecs = embs[idx1]

    # DIME mask & re‑rank (no 2nd index call) -------------------------
    q_tilde = dime_filter(q_vec, top_vecs, scores1, keep_frac=0.6, tau=0.7)
    reranked_scores = top_vecs @ (q_tilde / np.linalg.norm(q_tilde))
    order = np.argsort(-reranked_scores)

    # Pretty print -----------------------------------------------------
    print("First‑stage vs. DIME rerank:")
    rows = []
    for rank, i in enumerate(idx1):
        rows.append([
            rank + 1,
            ids[i],
            f"{scores1[rank]:.3f}",
            f"{reranked_scores[rank]:.3f}",
            docs[i][:50] + "…",
        ])
    print(tabulate(rows, headers=["Rank", "ID", "Score1", "DIME", "Text"], tablefmt="github"))
# Out:
# Loading SBERT …
# Indexed 5 docs, dim=384
# === QUERY: capital of France ===
# First‑stage vs. DIME rerank:
# |   Rank | ID    |   Score1 |   DIME | Text                                                |
# |--------|-------|----------|--------|-----------------------------------------------------|
# |      1 | doc_1 |    0.78  |  0.828 | Paris is the capital of France and a major Europea… |
# |      2 | doc_5 |    0.528 |  0.602 | The City of Light is a popular nickname for Paris … |
# |      3 | doc_3 |    0.428 |  0.497 | Rome, the capital of Italy, hosts the Vatican City… |
# |      4 | doc_2 |    0.275 |  0.36  | Berlin is the vibrant capital of Germany, known fo… |
# |      5 | doc_4 |    0.255 |  0.341 | Toronto is the largest city in Canada and the capi… |
# === QUERY: German capital city ===
# First‑stage vs. DIME rerank:
# |   Rank | ID    |   Score1 |   DIME | Text                                                |
# |--------|-------|----------|--------|-----------------------------------------------------|
# |      1 | doc_2 |    0.657 |  0.677 | Berlin is the vibrant capital of Germany, known fo… |
# |      2 | doc_1 |    0.441 |  0.547 | Paris is the capital of France and a major Europea… |
# |      3 | doc_3 |    0.395 |  0.46  | Rome, the capital of Italy, hosts the Vatican City… |
# |      4 | doc_5 |    0.326 |  0.448 | The City of Light is a popular nickname for Paris … |
# |      5 | doc_4 |    0.191 |  0.305 | Toronto is the largest city in Canada and the capi… |

# %% [markdown]
# #Experiment 2

# %%
# !pip install datasets sentence-transformers numpy tabulate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: sentence-transformers in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (5.0.0)
# Requirement already satisfied: numpy in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: tabulate in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: filelock in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (0.33.4)
# Requirement already satisfied: packaging in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.53.2)
# Requirement already satisfied: torch>=1.11.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: setuptools in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-4.0.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install --upgrade datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: datasets in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (4.0.0)
# Requirement already satisfied: filelock in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (0.33.4)
# Requirement already satisfied: packaging in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in /Users/bavalpreetsingh/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import numpy as np
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from tabulate import tabulate

# ---- CONFIG ----
N_QUERIES = 50      # Scan this many queries to find an improvement
TOP_K = 5           # 1 positive, 4 negatives
KEEP_FRAC = 0.4
TAU = 0.7

# ---- LOAD DATA ----
dataset = load_dataset("ms_marco", "v2.1")
val = dataset["validation"]
model = SentenceTransformer("all-MiniLM-L6-v2")

def softmax(x, tau=1.0):
    x = (x / tau) - np.max(x)
    return np.exp(x) / np.exp(x).sum()

found = 0
for i in range(N_QUERIES):
    query = val[i]["query"]
    answers = val[i]["answers"]
    passages = val[i]["passages"]["passage_text"]
    is_selected = val[i]["passages"]["is_selected"]

    # Ensure at least one positive and enough negatives
    positives = [txt for sel, txt in zip(is_selected, passages) if sel == 1]
    negatives = [txt for sel, txt in zip(is_selected, passages) if sel == 0]
    if not positives or len(negatives) < (TOP_K - 1):
        continue

    # Build pool: 1 positive, TOP_K-1 negatives
    candidates = [positives[0]] + negatives[:TOP_K-1]
    labels = ["✔️"] + [""] * (TOP_K-1)
    gold_idx = 0  # positive always at position 0

    # --- Encode ---
    cand_vecs = model.encode(candidates, convert_to_numpy=True)
    q_vec = model.encode(query, convert_to_numpy=True)

    # --- Baseline ---
    scores = cand_vecs @ q_vec
    ranked_idx = np.argsort(-scores)
    base_rank = list(ranked_idx).index(gold_idx) + 1

    # --- DIME ---
    top_idx = ranked_idx[:TOP_K]
    top_vecs = cand_vecs[top_idx]
    top_scores = scores[top_idx]
    weights = softmax(top_scores, TAU)
    centroid = np.average(top_vecs, axis=0, weights=weights)
    importance = q_vec * centroid
    keep_count = int(len(importance) * KEEP_FRAC)
    keep_dims = np.argsort(importance)[-keep_count:]
    mask = np.zeros_like(importance)
    mask[keep_dims] = 1
    q_dime = q_vec * mask
    dime_scores = cand_vecs @ q_dime
    dime_ranked_idx = np.argsort(-dime_scores)
    dime_rank = list(dime_ranked_idx).index(gold_idx) + 1

    if dime_rank < base_rank:
        print("="*100)
        print(f"Query: {query}")
        print(f"Ground-truth answer: {answers[0] if answers else ''}\n")
        print("BASELINE ranking:")
        print(tabulate(
            [(i+1, candidates[j][:90].replace('\n',' '), labels[j], scores[j])
             for i, j in enumerate(ranked_idx)],
            headers=["Rank", "Passage", "Gold", "Score"], tablefmt="github"))
        print("\nDIME RE-RANKING:")
        print(tabulate(
            [(i+1, candidates[j][:90].replace('\n',' '), labels[j], dime_scores[j])
             for i, j in enumerate(dime_ranked_idx)],
            headers=["Rank", "Passage", "Gold", "Score"], tablefmt="github"))
        print(f"\nGold passage baseline position: {base_rank}")
        print(f"Gold passage DIME position: {dime_rank}")
        print("Did DIME improve the rank? YES\n")
        found += 1
    if found >= 1:
        break

if found == 0:
    print(f"Tried {N_QUERIES} examples but did not find a case where DIME improved the rank. Try increasing N_QUERIES or KEEP_FRAC or use TOP_K=10.")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# v2.1/validation-00000-of-00001.parquet:   0%|          | 0.00/210M [00:00<?, ?B/s]
# v2.1/train-00000-of-00007.parquet:   0%|          | 0.00/240M [00:00<?, ?B/s]
# v2.1/train-00001-of-00007.parquet:   0%|          | 0.00/240M [00:00<?, ?B/s]
# v2.1/train-00002-of-00007.parquet:   0%|          | 0.00/241M [00:00<?, ?B/s]
# v2.1/train-00003-of-00007.parquet:   0%|          | 0.00/242M [00:00<?, ?B/s]
# v2.1/train-00004-of-00007.parquet:   0%|          | 0.00/242M [00:00<?, ?B/s]
# v2.1/train-00005-of-00007.parquet:   0%|          | 0.00/242M [00:00<?, ?B/s]
# v2.1/train-00006-of-00007.parquet:   0%|          | 0.00/244M [00:00<?, ?B/s]
# v2.1/test-00000-of-00001.parquet:   0%|          | 0.00/204M [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/101093 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/808731 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/101092 [00:00<?, ? examples/s]
# ====================================================================================================
# Query: why did rachel carson write an obligation to endure
# Ground-truth answer: Rachel Carson writes The Obligation to Endure because believes that as man tries to eliminate unwanted insects and weeds, however he is actually causing more problems by polluting the environment.
#
# BASELINE ranking:
# |   Rank | Passage                                                                                    | Gold   |    Score |
# |--------|--------------------------------------------------------------------------------------------|--------|----------|
# |      1 | Carson subtly defers her writing in just the right writing technique for it to not be subj |        | 0.802501 |
# |      2 | The Obligation to Endure by Rachel Carson Rachel Carson's essay on The Obligation to Endur | ✔️      | 0.793415 |
# |      3 | Ashley Deemer. Eastern gateway Community College. Abstract. In the following pages the rea |        | 0.694328 |
# |      4 | The essay starts out with the statement “The history of life on earth has been an interact |        | 0.513243 |
# |      5 | Read to write - grow a love of books (even if it's a comic book) Organizing an argument in |        | 0.154978 |
#
# DIME RE-RANKING:
# |   Rank | Passage                                                                                    | Gold   |    Score |
# |--------|--------------------------------------------------------------------------------------------|--------|----------|
# |      1 | The Obligation to Endure by Rachel Carson Rachel Carson's essay on The Obligation to Endur | ✔️      | 0.724194 |
# |      2 | Carson subtly defers her writing in just the right writing technique for it to not be subj |        | 0.723482 |
# |      3 | Ashley Deemer. Eastern gateway Community College. Abstract. In the following pages the rea |        | 0.646912 |
# |      4 | The essay starts out with the statement “The history of life on earth has been an interact |        | 0.495389 |
# |      5 | Read to write - grow a love of books (even if it's a comic book) Organizing an argument in |        | 0.216046 |
#
# Gold passage baseline position: 2
# Gold passage DIME position: 1
# Did DIME improve the rank? YES
